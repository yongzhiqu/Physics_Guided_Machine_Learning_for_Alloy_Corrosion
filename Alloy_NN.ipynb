# %%
import os
import pandas as pd

# Get the current working directory
cwd = os.getcwd()

# Define the data path relative to the current directory
data_path = os.path.join(cwd, 'New_Modified_Copy.xlsx')

# Load the Excel file
data1 = pd.read_excel(data_path)

data1.head()
# Out:
#   Materials Index Processing (w/ direction)  Input ->  Combined  Input1  \
# 0             NaN                       NaN       NaN       NaN     NaN
# 1            ZK60                      LPBF       NaN   225.957  218.30
# 2            ZK60                      LPBF       NaN   225.981  213.58
# 3            ZK60                      LPBF       NaN   225.945  220.66
# 4            ZK60                      LPBF       NaN   225.951  219.48
#
#    Input2   Cr  Unnamed: 7     Mn  Unnamed: 9  ...       Rp      1/Rp  \
# 0     NaN -0.9         NaN -1.185         NaN  ...      NaN       NaN
# 1   7.657  0.0         0.0  0.000         0.0  ...  5499.90  0.000182
# 2  12.401  0.0         0.0  0.000         0.0  ...  5247.86  0.000191
# 3   5.285  0.0         0.0  0.000         0.0  ...  2182.92  0.000458
# 4   6.471  0.0         0.0  0.000         0.0  ...  2486.40  0.000402
#
#      Scaled  Rs solution (Ohm-cm2)  R1 polarization (Ohm-cm2)  \
# 0       NaN                    NaN                        NaN
# 1  8.612485                  25.80                      296.1
# 2  8.565576                  25.06                      237.8
# 3  7.688419                  28.22                       38.7
# 4  7.818591                  35.50                      148.9
#
#    C1 polarization (Ohm-cm2)  C1 time constant  R2 passivation (Ohm-cm2)  \
# 0                        NaN               NaN                       NaN
# 1                   0.000007              0.72                    5178.0
# 2                   0.000007              0.74                    4985.0
# 3                   0.000005              0.68                    2116.0
# 4                   0.000004              0.70                    2302.0
#
#    C2 passivation (Ohm-cm2)  C2 time constant
# 0                       NaN               NaN
# 1                  0.000064              0.87
# 2                  0.000010              0.80
# 3                  0.000050              0.77
# 4                  0.000034              0.74
#
# [5 rows x 85 columns]

# %%
import pandas as pd

data = data1.iloc[1:227, [4, 5, 66, 67, 68, 69, 71,77]]

# %%
data.head()
# Out:
#    Input1  Input2  Corrosion Potential to V_SCE (V)  Grain size (um)  \
# 1  218.30   7.657                            -1.373              2.5
# 2  213.58  12.401                            -1.361              2.1
# 3  220.66   5.285                            -1.420              7.0
# 4  219.48   6.471                            -1.394              3.4
# 5  218.30   7.657                            -1.373              2.5
#
#    GB ratio (HAGB)  GB ratio (LAGB)  Relative working potential to V_SCE (V)  \
# 1            0.808            0.192                                   -1.373
# 2            0.808            0.192                                   -1.361
# 3            0.808            0.192                                   -1.420
# 4            0.808            0.192                                   -1.394
# 5            0.808            0.192                                   -1.373
#
#      Scaled
# 1  8.612485
# 2  8.565576
# 3  7.688419
# 4  7.818591
# 5  8.449852

# %%
data.tail()
# Out:
#         Input1    Input2  Corrosion Potential to V_SCE (V)  Grain size (um)  \
# 222  157.02576  17.06947                         -0.734560             46.5
# 223  157.02576  17.06947                         -0.737630             46.5
# 224  157.02576  17.06947                         -0.648380             46.5
# 225  157.85676  18.58812                         -0.648377            639.0
# 226  157.85676  18.58812                         -0.617706            639.0
#
#      GB ratio (HAGB)  GB ratio (LAGB)  \
# 222             0.55             0.45
# 223             0.55             0.45
# 224             0.55             0.45
# 225             0.60             0.40
# 226             0.60             0.40
#
#      Relative working potential to V_SCE (V)     Scaled
# 222                                -0.734560  10.432563
# 223                                -0.737630  10.470673
# 224                                -0.648380  10.325339
# 225                                -0.648377  10.593413
# 226                                -0.617706   9.915648

# %%
data.shape
# Out:
# (226, 8)

# %%
data.head(20)
# Out:
#       Input1    Input2  Corrosion Potential to V_SCE (V)  Grain size (um)  \
# 1   218.3000   7.65700                           -1.3730             2.50
# 2   213.5800  12.40100                           -1.3610             2.10
# 3   220.6600   5.28500                           -1.4200             7.00
# 4   219.4800   6.47100                           -1.3940             3.40
# 5   218.3000   7.65700                           -1.3730             2.50
# 6   213.5800  12.40100                           -1.3610             2.10
# 7   223.4920   4.66040                           -1.4043           151.60
# 8   223.4920   4.66040                           -1.4128             1.50
# 9   233.2388   2.01906                           -1.5510            22.00
# 10  232.7196   2.48942                           -1.5130            23.00
# 11  232.3656   2.75815                           -1.5180            23.00
# 12  232.0352   3.10060                           -1.4950            26.00
# 13  226.3476   5.96263                           -1.2700             7.00
# 14  224.9552   7.55254                           -1.2200             8.00
# 15  226.3476   5.96263                           -1.2200             7.00
# 16  224.9552   7.55254                           -1.2100             8.00
# 17  217.1200  15.27400                           -1.4740             5.19
# 18  217.1200  15.27400                           -1.3020             4.94
# 19  217.1200  15.27400                           -1.3250             5.44
# 20  232.7432   1.17300                           -1.5220           104.00
#
#     GB ratio (HAGB)  GB ratio (LAGB)  Relative working potential to V_SCE (V)  \
# 1             0.808            0.192                                  -1.3730
# 2             0.808            0.192                                  -1.3610
# 3             0.808            0.192                                  -1.4200
# 4             0.808            0.192                                  -1.3940
# 5             0.808            0.192                                  -1.3730
# 6             0.808            0.192                                  -1.3610
# 7             0.710            0.290                                  -1.4043
# 8             0.710            0.290                                  -1.4128
# 9             0.510            0.490                                  -1.5510
# 10            0.510            0.490                                  -1.5130
# 11            0.510            0.490                                  -1.5180
# 12            0.510            0.490                                  -1.4950
# 13            0.600            0.400                                  -1.2700
# 14            0.600            0.400                                  -1.2200
# 15            0.600            0.400                                  -1.2200
# 16            0.600            0.400                                  -1.2100
# 17            0.500            0.500                                  -1.4740
# 18            0.500            0.500                                  -1.3020
# 19            0.500            0.500                                  -1.3250
# 20            0.660            0.340                                  -1.5220
#
#       Scaled
# 1   8.612485
# 2   8.565576
# 3   7.688419
# 4   7.818591
# 5   8.449852
# 6   8.296554
# 7   7.007538
# 8   7.191309
# 9   4.415824
# 10  4.550080
# 11  4.903718
# 12  5.251488
# 13  7.073998
# 14  7.673463
# 15  7.598525
# 16  8.359198
# 17  3.217275
# 18  5.061265
# 19  3.917210
# 20  7.734034

# %%
# `data` is your DataFrame
indices_to_drop = [9,10,11,17]
data = data.drop(indices_to_drop)

# %%
data.head(20)
# Out:
#       Input1    Input2  Corrosion Potential to V_SCE (V)  Grain size (um)  \
# 1   218.3000   7.65700                           -1.3730             2.50
# 2   213.5800  12.40100                           -1.3610             2.10
# 3   220.6600   5.28500                           -1.4200             7.00
# 4   219.4800   6.47100                           -1.3940             3.40
# 5   218.3000   7.65700                           -1.3730             2.50
# 6   213.5800  12.40100                           -1.3610             2.10
# 7   223.4920   4.66040                           -1.4043           151.60
# 8   223.4920   4.66040                           -1.4128             1.50
# 12  232.0352   3.10060                           -1.4950            26.00
# 13  226.3476   5.96263                           -1.2700             7.00
# 14  224.9552   7.55254                           -1.2200             8.00
# 15  226.3476   5.96263                           -1.2200             7.00
# 16  224.9552   7.55254                           -1.2100             8.00
# 18  217.1200  15.27400                           -1.3020             4.94
# 19  217.1200  15.27400                           -1.3250             5.44
# 20  232.7432   1.17300                           -1.5220           104.00
# 21  230.9260   2.94302                           -1.4730            74.00
# 22  229.5100   4.32561                           -1.5727            68.00
# 23  228.0940   5.70130                           -1.5670            57.00
# 24  232.7432   1.17300                           -1.4620            27.00
#
#     GB ratio (HAGB)  GB ratio (LAGB)  Relative working potential to V_SCE (V)  \
# 1             0.808            0.192                                  -1.3730
# 2             0.808            0.192                                  -1.3610
# 3             0.808            0.192                                  -1.4200
# 4             0.808            0.192                                  -1.3940
# 5             0.808            0.192                                  -1.3730
# 6             0.808            0.192                                  -1.3610
# 7             0.710            0.290                                  -1.4043
# 8             0.710            0.290                                  -1.4128
# 12            0.510            0.490                                  -1.4950
# 13            0.600            0.400                                  -1.2700
# 14            0.600            0.400                                  -1.2200
# 15            0.600            0.400                                  -1.2200
# 16            0.600            0.400                                  -1.2100
# 18            0.500            0.500                                  -1.3020
# 19            0.500            0.500                                  -1.3250
# 20            0.660            0.340                                  -1.5220
# 21            0.660            0.340                                  -1.4730
# 22            0.660            0.340                                  -1.5727
# 23            0.660            0.340                                  -1.5670
# 24            0.660            0.340                                  -1.4620
#
#       Scaled
# 1   8.612485
# 2   8.565576
# 3   7.688419
# 4   7.818591
# 5   8.449852
# 6   8.296554
# 7   7.007538
# 8   7.191309
# 12  5.251488
# 13  7.073998
# 14  7.673463
# 15  7.598525
# 16  8.359198
# 18  5.061265
# 19  3.917210
# 20  7.734034
# 21  7.747381
# 22  7.726036
# 23  6.152945
# 24  7.826802

# %%
# `data` is your DataFrame
indices_to_drop = [19]
data = data.drop(indices_to_drop)

# %%
data.head(20)
# Out:
#       Input1    Input2  Corrosion Potential to V_SCE (V)  Grain size (um)  \
# 1   218.3000   7.65700                           -1.3730             2.50
# 2   213.5800  12.40100                           -1.3610             2.10
# 3   220.6600   5.28500                           -1.4200             7.00
# 4   219.4800   6.47100                           -1.3940             3.40
# 5   218.3000   7.65700                           -1.3730             2.50
# 6   213.5800  12.40100                           -1.3610             2.10
# 7   223.4920   4.66040                           -1.4043           151.60
# 8   223.4920   4.66040                           -1.4128             1.50
# 12  232.0352   3.10060                           -1.4950            26.00
# 13  226.3476   5.96263                           -1.2700             7.00
# 14  224.9552   7.55254                           -1.2200             8.00
# 15  226.3476   5.96263                           -1.2200             7.00
# 16  224.9552   7.55254                           -1.2100             8.00
# 18  217.1200  15.27400                           -1.3020             4.94
# 20  232.7432   1.17300                           -1.5220           104.00
# 21  230.9260   2.94302                           -1.4730            74.00
# 22  229.5100   4.32561                           -1.5727            68.00
# 23  228.0940   5.70130                           -1.5670            57.00
# 24  232.7432   1.17300                           -1.4620            27.00
# 25  230.9260   2.94302                           -1.5380             7.00
#
#     GB ratio (HAGB)  GB ratio (LAGB)  Relative working potential to V_SCE (V)  \
# 1             0.808            0.192                                  -1.3730
# 2             0.808            0.192                                  -1.3610
# 3             0.808            0.192                                  -1.4200
# 4             0.808            0.192                                  -1.3940
# 5             0.808            0.192                                  -1.3730
# 6             0.808            0.192                                  -1.3610
# 7             0.710            0.290                                  -1.4043
# 8             0.710            0.290                                  -1.4128
# 12            0.510            0.490                                  -1.4950
# 13            0.600            0.400                                  -1.2700
# 14            0.600            0.400                                  -1.2200
# 15            0.600            0.400                                  -1.2200
# 16            0.600            0.400                                  -1.2100
# 18            0.500            0.500                                  -1.3020
# 20            0.660            0.340                                  -1.5220
# 21            0.660            0.340                                  -1.4730
# 22            0.660            0.340                                  -1.5727
# 23            0.660            0.340                                  -1.5670
# 24            0.660            0.340                                  -1.4620
# 25            0.660            0.340                                  -1.5380
#
#       Scaled
# 1   8.612485
# 2   8.565576
# 3   7.688419
# 4   7.818591
# 5   8.449852
# 6   8.296554
# 7   7.007538
# 8   7.191309
# 12  5.251488
# 13  7.073998
# 14  7.673463
# 15  7.598525
# 16  8.359198
# 18  5.061265
# 20  7.734034
# 21  7.747381
# 22  7.726036
# 23  6.152945
# 24  7.826802
# 25  6.291939

# %%
data.shape
# Out:
# (221, 8)

# %%
input_data = data.iloc[:,0:7]

# %%
input_data.head()
# Out:
#    Input1  Input2  Corrosion Potential to V_SCE (V)  Grain size (um)  \
# 1  218.30   7.657                            -1.373              2.5
# 2  213.58  12.401                            -1.361              2.1
# 3  220.66   5.285                            -1.420              7.0
# 4  219.48   6.471                            -1.394              3.4
# 5  218.30   7.657                            -1.373              2.5
#
#    GB ratio (HAGB)  GB ratio (LAGB)  Relative working potential to V_SCE (V)
# 1            0.808            0.192                                   -1.373
# 2            0.808            0.192                                   -1.361
# 3            0.808            0.192                                   -1.420
# 4            0.808            0.192                                   -1.394
# 5            0.808            0.192                                   -1.373

# %%
input_data.shape
# Out:
# (221, 7)

# %%
Output_data = data.iloc[:,-1]

# %%
Output_data.head()
# Out:
# 1    8.612485
# 2    8.565576
# 3    7.688419
# 4    7.818591
# 5    8.449852
# Name: Scaled, dtype: float64

# %%
Output_data =Output_data.values.reshape(-1, 1)
Output_data .shape
# Out:
# (221, 1)

# %% [markdown]
# # regular NN model

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Function to split data for training, validation, and testing
def split_data(inputs, outputs, val_size=0.2, test_size=0.2):
    inputs_train, inputs_temp, outputs_train, outputs_temp = train_test_split(
        inputs, outputs, test_size=val_size+test_size, random_state=42)
    val_split = test_size / (val_size + test_size)
    inputs_val, inputs_test, outputs_val, outputs_test = train_test_split(
        inputs_temp, outputs_temp, test_size=val_split, random_state=42)
    return inputs_train, inputs_val, inputs_test, outputs_train, outputs_val, outputs_test

materials_data = [
    split_data(input_data[0:36], Output_data[0:36]),
    split_data(input_data[36:174], Output_data[36:174]),
    split_data(input_data[174:221], Output_data[174:221])
]


materials_data = [
    (np.asarray(data[0]), np.asarray(data[1]), np.asarray(data[2]), 
     np.asarray(data[3]), np.asarray(data[4]), np.asarray(data[5])) 
    for data in materials_data
]

# Custom Dataset class
class MaterialDataset(Dataset):
    def __init__(self, inputs, outputs):
        self.inputs = torch.tensor(inputs, dtype=torch.float32)
        self.outputs = torch.tensor(outputs, dtype=torch.float32)

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return self.inputs[idx], self.outputs[idx]

# Neural network with separate parameters for each material
class MaterialSpecificModel(nn.Module):
    def __init__(self, num_materials=3, num_features=7, num_outputs=1):
        super(MaterialSpecificModel, self).__init__()
        self.common_layers = nn.Sequential(
            nn.Linear(num_features, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU()
        )
        self.output_layer = nn.Linear(64, num_outputs)

    def forward(self, x, material_idx):
        x = self.common_layers(x)
        x = self.output_layer(x)
        return x, material_idx

# Custom loss function
def custom_loss_function(outputs, targets, model, inputs, material_idx):
    # Calculate MSE loss
    mse_loss = torch.mean((outputs - targets) ** 2)

    # Combine the losses
    combined_loss = mse_loss 
    return combined_loss

# Initialize the network and optimizer
model = MaterialSpecificModel()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# DataLoaders for training, validation, and testing
train_loaders = [DataLoader(MaterialDataset(data[0], data[3]), batch_size=8, shuffle=True) for data in materials_data]
val_loaders = [DataLoader(MaterialDataset(data[1], data[4]), batch_size=8) for data in materials_data]
test_loaders = [DataLoader(MaterialDataset(data[2], data[5]), batch_size=8) for data in materials_data]

# Training and validation loops
num_epochs = 250
training_losses = []
validation_losses = []

for epoch in range(num_epochs):
    total_train_loss = 0.0
    total_val_loss = 0.0

    model.train()
    for material_idx, train_loader in enumerate(train_loaders):
        for inputs, targets in train_loader:
            optimizer.zero_grad()  # Clear gradients for each batch
            outputs, _ = model(inputs, material_idx)
            loss = custom_loss_function(outputs, targets, model, inputs, material_idx)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
    model.eval()
    with torch.no_grad():
        for material_idx, val_loader in enumerate(val_loaders):
            for inputs, targets in val_loader:
                outputs, _ = model(inputs, material_idx)
                loss = custom_loss_function(outputs, targets, model, inputs, material_idx)
                total_val_loss += loss.item()

    avg_train_loss = total_train_loss / sum(len(loader) for loader in train_loaders)
    avg_val_loss = total_val_loss / sum(len(loader) for loader in val_loaders)
    training_losses.append(avg_train_loss)
    validation_losses.append(avg_val_loss)

    if (epoch + 1) % 10 == 0:
        print(f'Epoch {epoch + 1}/{num_epochs} - Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}')

# Plotting the training and validation losses
plt.figure(figsize=(10, 5))
plt.plot(training_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.title('Training and Validation Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 10/250 - Training Loss: 14.4418, Validation Loss: 8.3988
# Epoch 20/250 - Training Loss: 22.1498, Validation Loss: 11.8260
# Epoch 30/250 - Training Loss: 9.4564, Validation Loss: 7.0099
# Epoch 40/250 - Training Loss: 7.7133, Validation Loss: 5.1885
# Epoch 50/250 - Training Loss: 6.9695, Validation Loss: 5.0335
# Epoch 60/250 - Training Loss: 9.9169, Validation Loss: 7.1773
# Epoch 70/250 - Training Loss: 5.7230, Validation Loss: 4.5108
# Epoch 80/250 - Training Loss: 5.9767, Validation Loss: 3.8837
# Epoch 90/250 - Training Loss: 6.2624, Validation Loss: 3.4016
# Epoch 100/250 - Training Loss: 5.7688, Validation Loss: 3.6051
# Epoch 110/250 - Training Loss: 4.9677, Validation Loss: 3.5959
# Epoch 120/250 - Training Loss: 4.3595, Validation Loss: 3.1634
# Epoch 130/250 - Training Loss: 4.4675, Validation Loss: 3.5594
# Epoch 140/250 - Training Loss: 4.1113, Validation Loss: 2.7522
# Epoch 150/250 - Training Loss: 8.3896, Validation Loss: 6.6340
# Epoch 160/250 - Training Loss: 3.8190, Validation Loss: 3.1239
# Epoch 170/250 - Training Loss: 4.9261, Validation Loss: 2.4698
# Epoch 180/250 - Training Loss: 3.6588, Validation Loss: 2.2930
# Epoch 190/250 - Training Loss: 3.4289, Validation Loss: 2.3086
# Epoch 200/250 - Training Loss: 3.9600, Validation Loss: 3.6749
# Epoch 210/250 - Training Loss: 3.9068, Validation Loss: 2.4566
# Epoch 220/250 - Training Loss: 4.3199, Validation Loss: 3.0618
# Epoch 230/250 - Training Loss: 2.9339, Validation Loss: 2.5344
# Epoch 240/250 - Training Loss: 3.0222, Validation Loss: 2.6012
# Epoch 250/250 - Training Loss: 2.9645, Validation Loss: 2.9007

# %%
# Testing phase with prediction collection
def test_model_with_predictions(model, test_loaders):
    model.eval()
    test_losses = []
    all_predictions = []
    all_targets = []
    
    with torch.no_grad():
        for material_idx, test_loader in enumerate(test_loaders):
            total_test_loss = 0.0
            material_predictions = []
            material_targets = []
            
            for inputs, targets in test_loader:
                outputs, _ = model(inputs, material_idx)
                loss = custom_loss_function(outputs, targets, model, inputs, material_idx)
                total_test_loss += loss.item()
                
                material_predictions.extend(outputs.numpy().flatten())
                material_targets.extend(targets.numpy().flatten())
                
            avg_test_loss = total_test_loss / len(test_loader)
            test_losses.append(avg_test_loss)
            all_predictions.append(material_predictions)
            all_targets.append(material_targets)
            print(f'Material {material_idx + 1} - Test Loss: {avg_test_loss:.4f}')
    
    return test_losses, all_predictions, all_targets

# Execute the testing phase
test_losses, all_predictions, all_targets = test_model_with_predictions(model, test_loaders)
# Out:
# Material 1 - Test Loss: 2.2060
# Material 2 - Test Loss: 4.2959
# Material 3 - Test Loss: 6.6709

# %%
# Plotting the comparison between predicted and actual values
def plot_comparisons(all_predictions, all_targets):
    materials = len(all_predictions)
    plt.figure(figsize=(15, 5 * materials))

    for i in range(materials):
        plt.subplot(materials, 1, i + 1)
        plt.plot(all_targets[i], label='Actual')
        plt.plot(all_predictions[i], label='Predicted', alpha=0.7)
        plt.title(f'Material {i + 1} - Predicted vs Actual')
        plt.xlabel('Sample Index')
        plt.ylabel('Value')
        plt.legend()

    plt.tight_layout()
    plt.show()

# Plot the comparisons
plot_comparisons(all_predictions, all_targets)

# %%
import numpy as np
import torch

# Testing phase with prediction collection and inversion from log scale
def test_model_with_predictions_and_invert_scale(model, test_loaders):
    model.eval()
    test_losses = []
    all_predictions = []
    all_targets = []
    
    with torch.no_grad():
        for material_idx, test_loader in enumerate(test_loaders):
            total_test_loss = 0.0
            material_predictions = []
            material_targets = []
            
            for inputs, targets in test_loader:
                outputs, _ = model(inputs, material_idx)
                # Calculate loss before inverting the scale
                loss = custom_loss_function(outputs, targets, model, inputs, material_idx)
                total_test_loss += loss.item()
                
                # Invert the scale of outputs from log scale back to original
                inverted_outputs = np.exp(-outputs.numpy().flatten())
                material_predictions.extend(inverted_outputs)

                # Invert the scale of targets from log scale back to original
                inverted_targets = np.exp(-targets.numpy().flatten())
                material_targets.extend(inverted_targets)
                
            avg_test_loss = total_test_loss / len(test_loader)
            test_losses.append(avg_test_loss)
            all_predictions.append(material_predictions)
            all_targets.append(material_targets)
            print(f'Material {material_idx + 1} - Test Loss: {avg_test_loss:.4f}')
    
    return test_losses, all_predictions, all_targets

# Execute the testing phase
test_losses, all_predictions, all_targets = test_model_with_predictions_and_invert_scale(model, test_loaders)
# Out:
# Material 1 - Test Loss: 2.2060
# Material 2 - Test Loss: 4.2959
# Material 3 - Test Loss: 6.6709

# %%
import numpy as np
import torch

def test_model_with_predictions_and_invert_scale(model, test_loaders):
    model.eval()
    test_losses = []
    all_predictions = []
    all_targets = []
    
    with torch.no_grad():
        for material_idx, test_loader in enumerate(test_loaders):
            total_test_loss = 0.0
            material_predictions = []
            material_targets = []
            
            for inputs, targets in test_loader:
                outputs, _ = model(inputs, material_idx)
                # Calculate loss before inverting the scale
                loss = custom_loss_function(outputs, targets, model, inputs, material_idx)
                total_test_loss += loss.item()
                
                # Invert the scale of outputs from log scale back to original
                inverted_outputs = np.exp(-outputs.detach().cpu().numpy().flatten())
                material_predictions.extend(inverted_outputs)

                # Invert the scale of targets from log scale back to original
                inverted_targets = np.exp(-targets.detach().cpu().numpy().flatten())
                material_targets.extend(inverted_targets)
                
            avg_test_loss = total_test_loss / len(test_loader)
            test_losses.append(avg_test_loss)
            all_predictions.append(material_predictions)
            all_targets.append(material_targets)
            print(f'Material {material_idx + 1} - Test Loss: {avg_test_loss:.4f}')
    
    return test_losses, all_predictions, all_targets

# Execute the testing phase
test_losses, all_predictions, all_targets = test_model_with_predictions_and_invert_scale(model, test_loaders)

# Printing all original predicted and target values
for i in range(len(all_predictions)):
    print(f"Material {i+1} Predictions: {all_predictions[i]}")
    print(f"Material {i+1} Targets: {all_targets[i]}")
    
import numpy as np

def calculate_mse(predictions, targets):
    """Calculate the mean squared error between predictions and targets."""
    predictions = np.array(predictions)
    targets = np.array(targets)
    return np.mean((predictions - targets) ** 2)

# Assuming all_predictions and all_targets are lists of lists where each sublist corresponds to a material type
mse_scores = []
for i in range(len(all_predictions)):
    mse = calculate_mse(all_predictions[i], all_targets[i])
    mse_scores.append(mse)
    print(f"Material {i+1} MSE: {mse:.9f}")

# If you want to also display the overall MSE for all materials combined
all_material_predictions = [pred for sublist in all_predictions for pred in sublist]
all_material_targets = [target for sublist in all_targets for target in sublist]
overall_mse = calculate_mse(all_material_predictions, all_material_targets)
print(f"Overall MSE: {overall_mse:.8f}")
# Out:
# Material 1 - Test Loss: 2.2060
# Material 2 - Test Loss: 4.2959
# Material 3 - Test Loss: 6.6709
# Material 1 Predictions: [0.00094081386, 0.0020115976, 0.001953137, 0.0005698252, 0.0022217538, 0.0023803057, 0.00029892512, 0.00016126003]
# Material 1 Targets: [0.002127207, 0.0016795004, 0.001985226, 0.00021393207, 0.0020267735, 0.005239717, 0.001178148, 0.006337538]
# Material 2 Predictions: [0.00010801374, 1.0724765e-05, 9.641005e-06, 6.7814117e-06, 0.0021649338, 0.0009766035, 1.2315819e-06, 2.703462e-06, 4.5915687e-05, 1.3227432e-06, 2.0471696e-06, 3.9310682e-05, 3.1406626e-06, 0.0010314704, 4.953648e-06, 2.2423867e-06, 2.7873143e-06, 3.511905e-06, 2.2956135e-06, 2.4621552e-06, 3.1377049e-06, 2.7890455e-06, 4.8080146e-05, 0.0010506072, 1.3227444e-06, 3.61309e-05, 5.7081717e-05, 2.2347278e-05]
# Material 2 Targets: [6.2840336e-05, 5.746271e-06, 2.816898e-07, 6.1720784e-06, 0.0016111361, 0.0006091098, 8.110998e-05, 0.00032215624, 0.00046964173, 1.4088532e-06, 1.5953807e-06, 7.87321e-06, 2.5379609e-06, 0.00068771536, 3.999334e-05, 2.290561e-05, 5.8323712e-06, 5.215132e-06, 8.569762e-06, 2.5985943e-05, 1.8312074e-06, 0.0013795657, 9.208508e-06, 0.0010634112, 1.7186941e-06, 3.3320342e-05, 2.3887513e-05, 0.00032699862]
# Material 3 Predictions: [0.00023200615, 0.00042536468, 2.3335226e-05, 0.0008270324, 2.1212629e-05, 0.00010061546, 0.00044674292, 0.000833625, 2.4961379e-05, 0.00045614602]
# Material 3 Targets: [8.7670116e-05, 2.588019e-05, 0.00014446917, 2.2350772e-05, 1.7702901e-05, 1.8451114e-05, 2.8355982e-05, 3.003074e-05, 1.4555851e-06, 3.279159e-05]
# Material 1 MSE: 0.000006097
# Material 2 MSE: 0.000000102
# Material 3 MSE: 0.000000185
# Overall MSE: 0.00000116

# %%
import matplotlib.pyplot as plt

# Defining the data
all_predictions = [
    [0.00044404887, 0.0004808659, 0.00044056427, 0.00025237259, 0.0005806881, 0.0006510963, 9.546525e-05, 6.418152e-05],
   [0.00011568826, 2.7999577e-05, 1.52267785e-05, 1.4833863e-05, 0.0031858054, 0.0012513507, 3.1111886e-06, 5.4731468e-06, 4.2258147e-05, 3.7535253e-06, 3.647185e-06, 4.3606506e-05, 4.131525e-06, 0.00129566, 3.8988623e-05, 3.218703e-06, 4.109174e-06, 6.0059924e-06, 3.2753449e-06, 4.0232603e-06, 2.0862737e-05, 6.199256e-06, 7.782112e-05, 0.0013063886, 3.7535294e-06, 4.392534e-05, 6.759076e-05, 5.5115168e-05],
    [6.2251966e-05, 0.00031365952, 1.3705859e-05, 0.00054542435, 1.309075e-05, 4.9430128e-05, 0.00031369212, 0.00056111097, 1.8101176e-05, 0.0003282061]
]

all_targets = [
    [0.002127207, 0.0016795004, 0.001985226, 0.00021393207, 0.0020267735, 0.005239717, 0.001178148, 0.006337538],
    [6.2840336e-05, 5.746271e-06, 2.816898e-07, 6.1720784e-06, 0.0016111361, 0.0006091098, 8.110998e-05, 0.00032215624, 0.00046964173, 1.4088532e-06, 1.5953807e-06, 7.87321e-06, 2.5379609e-06, 0.00068771536, 3.999334e-05, 2.290561e-05, 5.8323712e-06, 5.215132e-06, 8.569762e-06, 2.5985943e-05, 1.8312074e-06, 0.0013795657, 9.208508e-06, 0.0010634112, 1.7186941e-06, 3.3320342e-05, 2.3887513e-05, 0.00032699862],
    [8.7670116e-05, 2.588019e-05, 0.00014446917, 2.2350772e-05, 1.7702901e-05, 1.8451114e-05, 2.8355982e-05, 3.003074e-05, 1.4555851e-06, 3.279159e-05]
]

# Plotting function
def plot_comparisons(all_predictions, all_targets):
    titles = ["Mg Based Alloys", "Fe-Ni Based Alloys", "Al Based Alloys"]
    materials = len(all_predictions)
    plt.figure(figsize=(15, 5 * materials))

    for i in range(materials):
        plt.subplot(materials, 1, i + 1)
        plt.plot(all_targets[i], 'o-', label='Actual', alpha=0.8)  # Circle markers for actual
        plt.plot(all_predictions[i], 'x-', label='Predicted', alpha=0.7)  # Cross markers for predicted
        plt.title(f'{titles[i]} - Predicted vs Actual')
        plt.xlabel('Sample Index')
        plt.ylabel('Value')
        plt.legend()

    plt.tight_layout()
    plt.show()

# Plot the comparisons using the provided data
plot_comparisons(all_predictions, all_targets)

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\wahid\anaconda3\envs\PyTorch\python.exe

# %%
import os
# Get the current working directory
cwd = os.getcwd()
print(f"Current Working Directory: {cwd}")
# Out:
# Current Working Directory: C:\Users\wahid

# %%
import numpy as np

# Define a function to calculate percentage errors
def calculate_percentage_errors(predictions, targets):
    predictions = np.array(predictions)
    targets = np.array(targets)
    targets = np.where(targets == 0, 1e-10, targets)
    percentage_errors = np.abs((predictions - targets) / targets) * 100
    return percentage_errors

# Material 1
material_1_predictions =[0.00044404887, 0.0004808659, 0.00044056427, 0.00025237259, 0.0005806881, 0.0006510963, 9.546525e-05, 6.418152e-05],
material_1_targets = [0.002127207, 0.0016795004, 0.001985226, 0.00021393207, 0.0020267735, 0.005239717, 0.001178148, 0.006337538]
material_1_errors = calculate_percentage_errors(material_1_predictions, material_1_targets)

# Material 2
material_2_predictions = [0.00011568826, 2.7999577e-05, 1.52267785e-05, 1.4833863e-05, 0.0031858054, 0.0012513507, 3.1111886e-06, 5.4731468e-06, 4.2258147e-05, 3.7535253e-06, 3.647185e-06, 4.3606506e-05, 4.131525e-06, 0.00129566, 3.8988623e-05, 3.218703e-06, 4.109174e-06, 6.0059924e-06, 3.2753449e-06, 4.0232603e-06, 2.0862737e-05, 6.199256e-06, 7.782112e-05, 0.0013063886, 3.7535294e-06, 4.392534e-05, 6.759076e-05, 5.5115168e-05],
material_2_targets =  [6.2840336e-05, 5.746271e-06, 2.816898e-07, 6.1720784e-06, 0.0016111361, 0.0006091098, 8.110998e-05, 0.00032215624, 0.00046964173, 1.4088532e-06, 1.5953807e-06, 7.87321e-06, 2.5379609e-06, 0.00068771536, 3.999334e-05, 2.290561e-05, 5.8323712e-06, 5.215132e-06, 8.569762e-06, 2.5985943e-05, 1.8312074e-06, 0.0013795657, 9.208508e-06, 0.0010634112, 1.7186941e-06, 3.3320342e-05, 2.3887513e-05, 0.00032699862]
material_2_errors = calculate_percentage_errors(material_2_predictions, material_2_targets)

# Material 3
material_3_predictions = [6.2251966e-05, 0.00031365952, 1.3705859e-05, 0.00054542435, 1.309075e-05, 4.9430128e-05, 0.00031369212, 0.00056111097, 1.8101176e-05, 0.0003282061]
material_3_targets = [8.7670116e-05, 2.588019e-05, 0.00014446917, 2.2350772e-05, 1.7702901e-05, 1.8451114e-05, 2.8355982e-05, 3.003074e-05, 1.4555851e-06, 3.279159e-05]
material_3_errors = calculate_percentage_errors(material_3_predictions, material_3_targets)

# Print percentage errors
print("Material 1 Percentage Errors:", material_1_errors)
print("Material 2 Percentage Errors:", material_2_errors)
print("Material 3 Percentage Errors:", material_3_errors)

# Calculate average percentage errors for each material
average_percentage_error_1 = np.mean(material_1_errors)
average_percentage_error_2 = np.mean(material_2_errors)
average_percentage_error_3 = np.mean(material_3_errors)

# Print average percentage errors
print("Average Percentage Error for Material 1:", average_percentage_error_1)
print("Average Percentage Error for Material 2:", average_percentage_error_2)
print("Average Percentage Error for Material 3:", average_percentage_error_3)
# Out:
# Material 1 Percentage Errors: [[79.12526284 71.3685153  77.80785311 17.96856357 71.34913694 87.57382698
#   91.897007   98.98727992]]
# Material 2 Percentage Errors: [[8.40987292e+01 3.87265167e+02 5.30551291e+03 1.40338214e+02
#   9.77365786e+01 1.05439266e+02 9.61642345e+01 9.83010893e+01
#   9.10020460e+01 1.66424160e+02 1.28609071e+02 4.53859303e+02
#   6.27891509e+01 8.84006197e+01 2.51221078e+00 8.59479708e+01
#   2.95453966e+01 1.51647245e+01 6.17802116e+01 8.45175513e+01
#   1.03928859e+03 9.95506371e+01 7.45100205e+02 2.28488660e+01
#   1.18394268e+02 3.18273984e+01 1.82954362e+02 8.31451374e+01]]
# Material 3 Percentage Errors: [  28.9929467  1111.9676092    90.51295235 2340.29311381   26.05308023
#   167.89779739 1006.26435015 1768.45535608 1143.56700271  900.88498301]
# Average Percentage Error for Material 1: 74.50968070902601
# Average Percentage Error for Material 2: 353.87564530073234
# Average Percentage Error for Material 3: 858.4889191623303

# %%
import numpy as np

# Define a function to calculate percentage errors
def calculate_percentage_errors(predictions, targets):
    predictions = np.array(predictions)
    targets = np.array(targets)
    
    # Calculate the range of the targets
    target_range = np.max(targets) - np.min(targets)
    if target_range == 0:
        target_range = 1e-10  # Avoid division by zero if all targets are the same
    
    # Calculate the percentage errors based on the target range
    percentage_errors = np.abs((predictions - targets) / target_range) * 100
    return percentage_errors

# Material 1
material_1_predictions = [0.00044404887, 0.0004808659, 0.00044056427, 0.00025237259, 0.0005806881, 0.0006510963, 9.546525e-05, 6.418152e-05]
material_1_targets = [0.002127207, 0.0016795004, 0.001985226, 0.00021393207, 0.0020267735, 0.005239717, 0.001178148, 0.006337538]
material_1_errors = calculate_percentage_errors(material_1_predictions, material_1_targets)

# Material 2
material_2_predictions = [0.00011568826, 2.7999577e-05, 1.52267785e-05, 1.4833863e-05, 0.0031858054, 0.0012513507, 3.1111886e-06, 5.4731468e-06, 4.2258147e-05, 3.7535253e-06, 3.647185e-06, 4.3606506e-05, 4.131525e-06, 0.00129566, 3.8988623e-05, 3.218703e-06, 4.109174e-06, 6.0059924e-06, 3.2753449e-06, 4.0232603e-06, 2.0862737e-05, 6.199256e-06, 7.782112e-05, 0.0013063886, 3.7535294e-06, 4.392534e-05, 6.759076e-05, 5.5115168e-05]
material_2_targets = [6.2840336e-05, 5.746271e-06, 2.816898e-07, 6.1720784e-06, 0.0016111361, 0.0006091098, 8.110998e-05, 0.00032215624, 0.00046964173, 1.4088532e-06, 1.5953807e-06, 7.87321e-06, 2.5379609e-06, 0.00068771536, 3.999334e-05, 2.290561e-05, 5.8323712e-06, 5.215132e-06, 8.569762e-06, 2.5985943e-05, 1.8312074e-06, 0.0013795657, 9.208508e-06, 0.0010634112, 1.7186941e-06, 3.3320342e-05, 2.3887513e-05, 0.00032699862]
material_2_errors = calculate_percentage_errors(material_2_predictions, material_2_targets)

# Material 3
material_3_predictions = [6.2251966e-05, 0.00031365952, 1.3705859e-05, 0.00054542435, 1.309075e-05, 4.9430128e-05, 0.00031369212, 0.00056111097, 1.8101176e-05, 0.0003282061]
material_3_targets = [8.7670116e-05, 2.588019e-05, 0.00014446917, 2.2350772e-05, 1.7702901e-05, 1.8451114e-05, 2.8355982e-05, 3.003074e-05, 1.4555851e-06, 3.279159e-05]
material_3_errors = calculate_percentage_errors(material_3_predictions, material_3_targets)

# Print percentage errors
print("Material 1 Percentage Errors:", material_1_errors)
print("Material 2 Percentage Errors:", material_2_errors)
print("Material 3 Percentage Errors:", material_3_errors)

# Calculate average percentage errors for each material
average_percentage_error_1 = np.mean(material_1_errors)
average_percentage_error_2 = np.mean(material_2_errors)
average_percentage_error_3 = np.mean(material_3_errors)

# Print average percentage errors
print("Average Percentage Error for Material 1:", average_percentage_error_1)
print("Average Percentage Error for Material 2:", average_percentage_error_2)
print("Average Percentage Error for Material 3:", average_percentage_error_3)
# Out:
# Material 1 Percentage Errors: [ 27.48638873  19.57399796  25.22470825   0.6277432   23.61493239
#   74.93331139  17.6804772  102.44546353]
# Material 2 Percentage Errors: [3.28073870e+00 1.38145979e+00 9.27774019e-01 5.37713684e-01
#  9.77536697e+01 3.98695808e+01 4.84207579e+00 1.96593243e+01
#  2.65314842e+01 1.45554563e-01 1.27373665e-01 2.21828216e+00
#  9.89266373e-02 3.77405082e+01 6.23716826e-02 1.22214068e+00
#  1.06974112e-01 4.90957094e-02 3.28671360e-01 1.36341823e+00
#  1.18145560e+00 8.52570186e+01 4.25939250e+00 1.50837592e+01
#  1.26320249e-01 6.58346151e-01 2.71304761e+00 1.68782138e+01]
# Material 3 Percentage Errors: [ 17.77324162 201.22517046  91.43418864 365.75097279   3.22497405
#   21.66158832 199.51680688 371.34949828  11.63916764 206.56395   ]
# Average Percentage Error for Material 1: 36.448377831033945
# Average Percentage Error for Material 2: 13.014453273835661
# Average Percentage Error for Material 3: 149.01395586930713

# %%
for epoch in range(num_epochs):
    print(f'Epoch {epoch + 1}/{num_epochs} - Training Loss: {training_losses[epoch]:.4f}, Validation Loss: {validation_losses[epoch]:.4f}')
# Out:
# Epoch 1/250 - Training Loss: 139.7584, Validation Loss: 52.4914
# Epoch 2/250 - Training Loss: 87.3460, Validation Loss: 47.6500
# Epoch 3/250 - Training Loss: 45.9678, Validation Loss: 27.6626
# Epoch 4/250 - Training Loss: 44.0357, Validation Loss: 20.1015
# Epoch 5/250 - Training Loss: 27.0784, Validation Loss: 11.4793
# Epoch 6/250 - Training Loss: 24.3024, Validation Loss: 9.6665
# Epoch 7/250 - Training Loss: 17.8676, Validation Loss: 9.8610
# Epoch 8/250 - Training Loss: 23.3733, Validation Loss: 14.5061
# Epoch 9/250 - Training Loss: 24.2951, Validation Loss: 14.1587
# Epoch 10/250 - Training Loss: 36.2567, Validation Loss: 22.4134
# Epoch 11/250 - Training Loss: 37.4727, Validation Loss: 21.2159
# Epoch 12/250 - Training Loss: 48.5275, Validation Loss: 33.0723
# Epoch 13/250 - Training Loss: 31.7881, Validation Loss: 26.6229
# Epoch 14/250 - Training Loss: 38.1049, Validation Loss: 23.2136
# Epoch 15/250 - Training Loss: 19.6911, Validation Loss: 12.5826
# Epoch 16/250 - Training Loss: 19.2694, Validation Loss: 11.8668
# Epoch 17/250 - Training Loss: 14.1901, Validation Loss: 9.4322
# Epoch 18/250 - Training Loss: 12.7602, Validation Loss: 9.2734
# Epoch 19/250 - Training Loss: 10.8900, Validation Loss: 8.0922
# Epoch 20/250 - Training Loss: 11.1806, Validation Loss: 7.9685
# Epoch 21/250 - Training Loss: 10.2487, Validation Loss: 7.4640
# Epoch 22/250 - Training Loss: 10.3062, Validation Loss: 7.3821
# Epoch 23/250 - Training Loss: 10.6414, Validation Loss: 7.0446
# Epoch 24/250 - Training Loss: 9.7474, Validation Loss: 7.2624
# Epoch 25/250 - Training Loss: 10.0628, Validation Loss: 6.9503
# Epoch 26/250 - Training Loss: 9.6614, Validation Loss: 7.1725
# Epoch 27/250 - Training Loss: 8.9462, Validation Loss: 6.6285
# Epoch 28/250 - Training Loss: 9.1504, Validation Loss: 6.9203
# Epoch 29/250 - Training Loss: 8.9699, Validation Loss: 6.4477
# Epoch 30/250 - Training Loss: 9.3413, Validation Loss: 6.7728
# Epoch 31/250 - Training Loss: 8.3687, Validation Loss: 6.3328
# Epoch 32/250 - Training Loss: 9.9458, Validation Loss: 7.2120
# Epoch 33/250 - Training Loss: 9.0339, Validation Loss: 6.7849
# Epoch 34/250 - Training Loss: 10.0574, Validation Loss: 8.2464
# Epoch 35/250 - Training Loss: 10.3545, Validation Loss: 7.2316
# Epoch 36/250 - Training Loss: 14.2945, Validation Loss: 9.9519
# Epoch 37/250 - Training Loss: 15.3269, Validation Loss: 9.1439
# Epoch 38/250 - Training Loss: 25.8098, Validation Loss: 18.1193
# Epoch 39/250 - Training Loss: 22.9376, Validation Loss: 21.2260
# Epoch 40/250 - Training Loss: 41.3921, Validation Loss: 33.3954
# Epoch 41/250 - Training Loss: 38.5228, Validation Loss: 20.4949
# Epoch 42/250 - Training Loss: 38.7827, Validation Loss: 24.2655
# Epoch 43/250 - Training Loss: 20.2855, Validation Loss: 9.3054
# Epoch 44/250 - Training Loss: 16.5901, Validation Loss: 10.0688
# Epoch 45/250 - Training Loss: 8.6785, Validation Loss: 7.3558
# Epoch 46/250 - Training Loss: 8.6609, Validation Loss: 6.6747
# Epoch 47/250 - Training Loss: 7.9188, Validation Loss: 6.4798
# Epoch 48/250 - Training Loss: 7.9195, Validation Loss: 6.4235
# Epoch 49/250 - Training Loss: 7.2918, Validation Loss: 6.2891
# Epoch 50/250 - Training Loss: 7.3563, Validation Loss: 6.1418
# Epoch 51/250 - Training Loss: 7.2186, Validation Loss: 6.2569
# Epoch 52/250 - Training Loss: 8.3676, Validation Loss: 5.9219
# Epoch 53/250 - Training Loss: 7.5880, Validation Loss: 5.9580
# Epoch 54/250 - Training Loss: 7.2487, Validation Loss: 6.1246
# Epoch 55/250 - Training Loss: 7.0674, Validation Loss: 5.8824
# Epoch 56/250 - Training Loss: 7.0584, Validation Loss: 5.8600
# Epoch 57/250 - Training Loss: 6.5380, Validation Loss: 5.7764
# Epoch 58/250 - Training Loss: 7.4875, Validation Loss: 5.8486
# Epoch 59/250 - Training Loss: 6.7226, Validation Loss: 6.0442
# Epoch 60/250 - Training Loss: 6.7161, Validation Loss: 5.8106
# Epoch 61/250 - Training Loss: 7.6914, Validation Loss: 6.2312
# Epoch 62/250 - Training Loss: 6.6596, Validation Loss: 5.5021
# Epoch 63/250 - Training Loss: 7.0552, Validation Loss: 5.8897
# Epoch 64/250 - Training Loss: 6.6065, Validation Loss: 5.5284
# Epoch 65/250 - Training Loss: 6.7781, Validation Loss: 5.6805
# Epoch 66/250 - Training Loss: 6.4346, Validation Loss: 5.4582
# Epoch 67/250 - Training Loss: 6.6496, Validation Loss: 5.7656
# Epoch 68/250 - Training Loss: 6.0445, Validation Loss: 5.3099
# Epoch 69/250 - Training Loss: 6.9282, Validation Loss: 5.8248
# Epoch 70/250 - Training Loss: 6.0388, Validation Loss: 5.1561
# Epoch 71/250 - Training Loss: 6.8855, Validation Loss: 5.5863
# Epoch 72/250 - Training Loss: 6.4059, Validation Loss: 5.4497
# Epoch 73/250 - Training Loss: 6.6425, Validation Loss: 5.4597
# Epoch 74/250 - Training Loss: 6.0212, Validation Loss: 4.9528
# Epoch 75/250 - Training Loss: 8.0371, Validation Loss: 5.9981
# Epoch 76/250 - Training Loss: 6.5560, Validation Loss: 5.1979
# Epoch 77/250 - Training Loss: 7.5392, Validation Loss: 5.4920
# Epoch 78/250 - Training Loss: 6.2517, Validation Loss: 5.2459
# Epoch 79/250 - Training Loss: 7.3247, Validation Loss: 6.1680
# Epoch 80/250 - Training Loss: 6.4721, Validation Loss: 5.4682
# Epoch 81/250 - Training Loss: 8.6997, Validation Loss: 7.0895
# Epoch 82/250 - Training Loss: 7.2983, Validation Loss: 5.9393
# Epoch 83/250 - Training Loss: 9.0702, Validation Loss: 7.9358
# Epoch 84/250 - Training Loss: 7.3274, Validation Loss: 6.2133
# Epoch 85/250 - Training Loss: 9.9096, Validation Loss: 8.5602
# Epoch 86/250 - Training Loss: 8.2080, Validation Loss: 6.6964
# Epoch 87/250 - Training Loss: 11.5209, Validation Loss: 8.6223
# Epoch 88/250 - Training Loss: 7.7824, Validation Loss: 6.1371
# Epoch 89/250 - Training Loss: 9.9698, Validation Loss: 7.6723
# Epoch 90/250 - Training Loss: 6.7895, Validation Loss: 6.0357
# Epoch 91/250 - Training Loss: 8.5942, Validation Loss: 6.9425
# Epoch 92/250 - Training Loss: 6.9037, Validation Loss: 5.5889
# Epoch 93/250 - Training Loss: 8.4400, Validation Loss: 6.7108
# Epoch 94/250 - Training Loss: 6.1869, Validation Loss: 5.3061
# Epoch 95/250 - Training Loss: 7.4175, Validation Loss: 6.2902
# Epoch 96/250 - Training Loss: 6.0218, Validation Loss: 4.9562
# Epoch 97/250 - Training Loss: 7.2093, Validation Loss: 5.6684
# Epoch 98/250 - Training Loss: 5.4786, Validation Loss: 4.6830
# Epoch 99/250 - Training Loss: 6.8735, Validation Loss: 5.0571
# Epoch 100/250 - Training Loss: 5.4067, Validation Loss: 4.7487
# Epoch 101/250 - Training Loss: 6.9286, Validation Loss: 5.8402
# Epoch 102/250 - Training Loss: 6.4483, Validation Loss: 4.5946
# Epoch 103/250 - Training Loss: 7.4679, Validation Loss: 5.7308
# Epoch 104/250 - Training Loss: 5.8168, Validation Loss: 4.9836
# Epoch 105/250 - Training Loss: 7.4240, Validation Loss: 6.0329
# Epoch 106/250 - Training Loss: 5.9123, Validation Loss: 5.1252
# Epoch 107/250 - Training Loss: 8.6903, Validation Loss: 7.1128
# Epoch 108/250 - Training Loss: 7.1808, Validation Loss: 4.7941
# Epoch 109/250 - Training Loss: 7.8920, Validation Loss: 6.0000
# Epoch 110/250 - Training Loss: 6.1532, Validation Loss: 4.3873
# Epoch 111/250 - Training Loss: 7.4257, Validation Loss: 5.1915
# Epoch 112/250 - Training Loss: 5.6155, Validation Loss: 4.6147
# Epoch 113/250 - Training Loss: 7.3161, Validation Loss: 5.5428
# Epoch 114/250 - Training Loss: 6.3844, Validation Loss: 4.8131
# Epoch 115/250 - Training Loss: 6.9031, Validation Loss: 5.7875
# Epoch 116/250 - Training Loss: 5.7837, Validation Loss: 4.4877
# Epoch 117/250 - Training Loss: 6.8624, Validation Loss: 5.2277
# Epoch 118/250 - Training Loss: 5.5376, Validation Loss: 4.4498
# Epoch 119/250 - Training Loss: 7.2400, Validation Loss: 5.5899
# Epoch 120/250 - Training Loss: 5.9172, Validation Loss: 4.6988
# Epoch 121/250 - Training Loss: 7.4747, Validation Loss: 6.3053
# Epoch 122/250 - Training Loss: 6.1856, Validation Loss: 5.3521
# Epoch 123/250 - Training Loss: 8.0004, Validation Loss: 6.5826
# Epoch 124/250 - Training Loss: 6.1119, Validation Loss: 5.3013
# Epoch 125/250 - Training Loss: 8.2150, Validation Loss: 6.8634
# Epoch 126/250 - Training Loss: 6.3577, Validation Loss: 4.9506
# Epoch 127/250 - Training Loss: 8.0716, Validation Loss: 6.1694
# Epoch 128/250 - Training Loss: 5.5511, Validation Loss: 4.4670
# Epoch 129/250 - Training Loss: 6.6484, Validation Loss: 5.2786
# Epoch 130/250 - Training Loss: 5.5767, Validation Loss: 3.8384
# Epoch 131/250 - Training Loss: 6.2689, Validation Loss: 4.3284
# Epoch 132/250 - Training Loss: 5.2514, Validation Loss: 3.6084
# Epoch 133/250 - Training Loss: 5.3603, Validation Loss: 4.0892
# Epoch 134/250 - Training Loss: 4.7325, Validation Loss: 3.5824
# Epoch 135/250 - Training Loss: 5.0401, Validation Loss: 3.9112
# Epoch 136/250 - Training Loss: 4.6537, Validation Loss: 3.5202
# Epoch 137/250 - Training Loss: 5.2291, Validation Loss: 3.9511
# Epoch 138/250 - Training Loss: 4.7507, Validation Loss: 3.3533
# Epoch 139/250 - Training Loss: 4.6866, Validation Loss: 3.6525
# Epoch 140/250 - Training Loss: 4.5739, Validation Loss: 3.6855
# Epoch 141/250 - Training Loss: 5.4925, Validation Loss: 4.2140
# Epoch 142/250 - Training Loss: 5.8772, Validation Loss: 4.7076
# Epoch 143/250 - Training Loss: 7.9141, Validation Loss: 6.8068
# Epoch 144/250 - Training Loss: 7.6870, Validation Loss: 5.4130
# Epoch 145/250 - Training Loss: 9.6347, Validation Loss: 8.8061
# Epoch 146/250 - Training Loss: 7.6928, Validation Loss: 5.2251
# Epoch 147/250 - Training Loss: 10.0774, Validation Loss: 5.5846
# Epoch 148/250 - Training Loss: 5.8947, Validation Loss: 3.6336
# Epoch 149/250 - Training Loss: 5.9026, Validation Loss: 4.4112
# Epoch 150/250 - Training Loss: 4.5499, Validation Loss: 3.5830
# Epoch 151/250 - Training Loss: 5.2653, Validation Loss: 4.2538
# Epoch 152/250 - Training Loss: 4.7771, Validation Loss: 3.3395
# Epoch 153/250 - Training Loss: 5.7972, Validation Loss: 4.2821
# Epoch 154/250 - Training Loss: 4.5410, Validation Loss: 3.8571
# Epoch 155/250 - Training Loss: 5.3586, Validation Loss: 5.1155
# Epoch 156/250 - Training Loss: 5.1767, Validation Loss: 3.1095
# Epoch 157/250 - Training Loss: 4.7645, Validation Loss: 3.2555
# Epoch 158/250 - Training Loss: 4.4633, Validation Loss: 3.0599
# Epoch 159/250 - Training Loss: 4.1312, Validation Loss: 3.2016
# Epoch 160/250 - Training Loss: 4.1281, Validation Loss: 2.9805
# Epoch 161/250 - Training Loss: 4.3520, Validation Loss: 3.4180
# Epoch 162/250 - Training Loss: 4.8264, Validation Loss: 2.9145
# Epoch 163/250 - Training Loss: 4.7251, Validation Loss: 3.7827
# Epoch 164/250 - Training Loss: 4.4366, Validation Loss: 2.8636
# Epoch 165/250 - Training Loss: 4.0686, Validation Loss: 3.2072
# Epoch 166/250 - Training Loss: 4.2254, Validation Loss: 2.9468
# Epoch 167/250 - Training Loss: 4.0885, Validation Loss: 3.0828
# Epoch 168/250 - Training Loss: 3.9666, Validation Loss: 2.9602
# Epoch 169/250 - Training Loss: 4.1559, Validation Loss: 2.8703
# Epoch 170/250 - Training Loss: 5.5339, Validation Loss: 4.1290
# Epoch 171/250 - Training Loss: 5.6343, Validation Loss: 3.2091
# Epoch 172/250 - Training Loss: 5.5161, Validation Loss: 4.5816
# Epoch 173/250 - Training Loss: 5.1962, Validation Loss: 3.7971
# Epoch 174/250 - Training Loss: 7.7865, Validation Loss: 6.1168
# Epoch 175/250 - Training Loss: 7.7845, Validation Loss: 5.0196
# Epoch 176/250 - Training Loss: 10.5258, Validation Loss: 9.5839
# Epoch 177/250 - Training Loss: 8.1318, Validation Loss: 6.4898
# Epoch 178/250 - Training Loss: 11.9891, Validation Loss: 9.1397
# Epoch 179/250 - Training Loss: 6.1990, Validation Loss: 4.8486
# Epoch 180/250 - Training Loss: 7.7907, Validation Loss: 5.4820
# Epoch 181/250 - Training Loss: 4.7474, Validation Loss: 3.5738
# Epoch 182/250 - Training Loss: 5.4201, Validation Loss: 4.0719
# Epoch 183/250 - Training Loss: 4.0003, Validation Loss: 3.2841
# Epoch 184/250 - Training Loss: 4.2908, Validation Loss: 3.6249
# Epoch 185/250 - Training Loss: 4.1975, Validation Loss: 2.8930
# Epoch 186/250 - Training Loss: 4.3615, Validation Loss: 3.5341
# Epoch 187/250 - Training Loss: 4.0962, Validation Loss: 2.7199
# Epoch 188/250 - Training Loss: 4.6203, Validation Loss: 3.1766
# Epoch 189/250 - Training Loss: 4.2868, Validation Loss: 2.7526
# Epoch 190/250 - Training Loss: 4.1755, Validation Loss: 3.0674
# Epoch 191/250 - Training Loss: 3.7313, Validation Loss: 2.7294
# Epoch 192/250 - Training Loss: 3.8376, Validation Loss: 2.5940
# Epoch 193/250 - Training Loss: 3.9747, Validation Loss: 2.9863
# Epoch 194/250 - Training Loss: 3.5554, Validation Loss: 2.5342
# Epoch 195/250 - Training Loss: 4.2886, Validation Loss: 3.5066
# Epoch 196/250 - Training Loss: 3.9644, Validation Loss: 2.5240
# Epoch 197/250 - Training Loss: 4.4329, Validation Loss: 3.3663
# Epoch 198/250 - Training Loss: 4.1044, Validation Loss: 2.5071
# Epoch 199/250 - Training Loss: 3.9205, Validation Loss: 2.9376
# Epoch 200/250 - Training Loss: 3.7015, Validation Loss: 2.6161
# Epoch 201/250 - Training Loss: 3.4656, Validation Loss: 2.4462
# Epoch 202/250 - Training Loss: 4.0045, Validation Loss: 3.6749
# Epoch 203/250 - Training Loss: 3.9951, Validation Loss: 2.3490
# Epoch 204/250 - Training Loss: 3.8810, Validation Loss: 2.9660
# Epoch 205/250 - Training Loss: 3.8415, Validation Loss: 2.9148
# Epoch 206/250 - Training Loss: 3.5088, Validation Loss: 2.6749
# Epoch 207/250 - Training Loss: 5.0089, Validation Loss: 4.2921
# Epoch 208/250 - Training Loss: 5.2908, Validation Loss: 3.3249
# Epoch 209/250 - Training Loss: 8.1002, Validation Loss: 5.1156
# Epoch 210/250 - Training Loss: 5.0671, Validation Loss: 3.7716
# Epoch 211/250 - Training Loss: 7.1667, Validation Loss: 5.7636
# Epoch 212/250 - Training Loss: 5.0694, Validation Loss: 3.8323
# Epoch 213/250 - Training Loss: 7.0552, Validation Loss: 4.1052
# Epoch 214/250 - Training Loss: 3.9340, Validation Loss: 2.7642
# Epoch 215/250 - Training Loss: 5.4700, Validation Loss: 4.2332
# Epoch 216/250 - Training Loss: 4.2980, Validation Loss: 3.2163
# Epoch 217/250 - Training Loss: 5.8355, Validation Loss: 4.5037
# Epoch 218/250 - Training Loss: 4.4052, Validation Loss: 2.6669
# Epoch 219/250 - Training Loss: 4.4898, Validation Loss: 3.6476
# Epoch 220/250 - Training Loss: 3.9554, Validation Loss: 2.6233
# Epoch 221/250 - Training Loss: 4.0592, Validation Loss: 3.0234
# Epoch 222/250 - Training Loss: 3.4301, Validation Loss: 2.3710
# Epoch 223/250 - Training Loss: 3.7315, Validation Loss: 3.1136
# Epoch 224/250 - Training Loss: 3.4408, Validation Loss: 2.2979
# Epoch 225/250 - Training Loss: 3.1795, Validation Loss: 2.5516
# Epoch 226/250 - Training Loss: 2.9967, Validation Loss: 2.2239
# Epoch 227/250 - Training Loss: 3.2529, Validation Loss: 2.6225
# Epoch 228/250 - Training Loss: 2.9518, Validation Loss: 2.2319
# Epoch 229/250 - Training Loss: 3.1118, Validation Loss: 2.6227
# Epoch 230/250 - Training Loss: 3.0076, Validation Loss: 2.3462
# Epoch 231/250 - Training Loss: 3.0528, Validation Loss: 2.3509
# Epoch 232/250 - Training Loss: 2.9903, Validation Loss: 2.6174
# Epoch 233/250 - Training Loss: 3.1049, Validation Loss: 2.0550
# Epoch 234/250 - Training Loss: 3.4223, Validation Loss: 3.0548
# Epoch 235/250 - Training Loss: 3.1149, Validation Loss: 2.2724
# Epoch 236/250 - Training Loss: 3.9834, Validation Loss: 3.1138
# Epoch 237/250 - Training Loss: 3.3692, Validation Loss: 2.0947
# Epoch 238/250 - Training Loss: 3.8007, Validation Loss: 3.2328
# Epoch 239/250 - Training Loss: 3.8648, Validation Loss: 2.4758
# Epoch 240/250 - Training Loss: 3.1940, Validation Loss: 2.1446
# Epoch 241/250 - Training Loss: 3.2907, Validation Loss: 2.7789
# Epoch 242/250 - Training Loss: 2.9633, Validation Loss: 2.1706
# Epoch 243/250 - Training Loss: 3.5983, Validation Loss: 3.4895
# Epoch 244/250 - Training Loss: 3.5230, Validation Loss: 2.4431
# Epoch 245/250 - Training Loss: 4.6803, Validation Loss: 4.3173
# Epoch 246/250 - Training Loss: 3.9590, Validation Loss: 2.8303
# Epoch 247/250 - Training Loss: 5.0714, Validation Loss: 3.7548
# Epoch 248/250 - Training Loss: 3.5782, Validation Loss: 2.1726
# Epoch 249/250 - Training Loss: 4.3000, Validation Loss: 2.8860
# Epoch 250/250 - Training Loss: 3.0619, Validation Loss: 2.0304

# %%
# Save the model's state dictionary
torch.save(model.state_dict(), 'material_specific_model_NN.pth')

# Optionally, you can save the optimizer state as well
torch.save(optimizer.state_dict(), 'optimizer_NN.pth')

# %% [markdown]
# # Comparision plot among Ground truth, NN and the PCNN

# %%
import matplotlib.pyplot as plt

# Defining the data
all_predictions_model1 = [
    [0.00057569897, 0.0015303588, 0.001539192, 0.0008056699, 0.0015494513, 0.0014318005, 0.0003708349, 0.00034132137],
    [7.0937465e-05, 8.293948e-06, 8.498094e-06, 8.234829e-06, 0.0006044002, 0.00031636172, 7.4889417e-06, 4.567256e-05, 4.1469066e-05, 2.163628e-06, 5.0449175e-06, 8.7604385e-06, 2.0028635e-06, 0.0003327197, 1.2450642e-05, 4.7087165e-06, 2.8133472e-06, 3.2469159e-06, 4.524176e-06, 1.5690588e-05, 8.2412e-06, 6.63382e-05, 1.4601825e-05, 0.00033940983, 2.163628e-06, 1.0464134e-05, 1.504931e-05, 4.507688e-05],
    [0.00015700866, 3.469539e-05, 4.1066338e-05, 5.4807755e-05, 4.0289215e-05, 4.2293665e-05, 7.44824e-05, 5.0209503e-05, 3.532572e-05, 7.062183e-05]
]

all_predictions_model2 = [
    [0.00057576015, 0.0010618076, 0.0010411938, 0.00046464682, 0.0012195064, 0.0014439968, 0.0001260252, 0.00013914402],
    [0.0001095022, 4.8870053e-05, 1.3812063e-05, 3.3375174e-05, 0.0034172966, 0.0009122986, 3.8201542e-06, 2.9788882e-05, 0.00013100311, 3.4337695e-06, 8.515682e-06, 2.1816657e-05, 5.590625e-06, 0.0009673433, 4.042762e-05, 1.0521402e-05, 9.987365e-06, 1.0825766e-05, 1.02362965e-05, 1.7387256e-05, 4.5416036e-05, 3.5754914e-05, 0.00021347657, 0.0009598809, 3.4337756e-06, 2.3972501e-05, 0.00015436704, 0.00013094152],
    [0.000103075, 0.00043426602, 4.209472e-05, 0.00061158504, 3.9310828e-05, 8.5994594e-05, 0.00061501865, 0.00060593337, 2.9414216e-05, 0.0006153305]
]

all_targets = [
    [0.002127207, 0.0016795004, 0.001985226, 0.00021393207, 0.0020267735, 0.005239717, 0.001178148, 0.006337538],
    [6.2840336e-05, 5.746271e-06, 2.816898e-07, 6.1720784e-06, 0.0016111361, 0.0006091098, 8.110998e-05, 0.00032215624, 0.00046964173, 1.4088532e-06, 1.5953807e-06, 7.87321e-06, 2.5379609e-06, 0.00068771536, 3.999334e-05, 2.290561e-05, 5.8323712e-06, 5.215132e-06, 8.569762e-06, 2.5985943e-05, 1.8312074e-06, 0.0013795657, 9.208508e-06, 0.0010634112, 1.7186941e-06, 3.3320342e-05, 2.3887513e-05, 0.00032699862],
    [8.7670116e-05, 2.588019e-05, 0.00014446917, 2.2350772e-05, 1.7702901e-05, 1.8451114e-05, 2.8355982e-05, 3.003074e-05, 1.4555851e-06, 3.279159e-05]
]

# Plotting function
def plot_comparisons(all_predictions_model1, all_predictions_model2, all_targets):
    titles = ["Mg Based Alloys", "Fe-Ni Based Alloys", "Al Based Alloys"]
    materials = len(all_predictions_model1)
    plt.figure(figsize=(15, 5 * materials))

    for i in range(materials):
        plt.subplot(materials, 1, i + 1)
        plt.plot(all_targets[i], 'o-', label='Ground TRuth', alpha=0.8)  # Circle markers for actual values
        plt.plot(all_predictions_model1[i], 'x-', label='Physics Constrained NN Model', alpha=0.7)  # Cross markers for predictions from model 1
        plt.plot(all_predictions_model2[i], 's-', label='Traditional NN Model', alpha=0.6)  # Square markers for predictions from model 2
        plt.title(f'{titles[i]} - Predicted vs Actual')
        plt.xlabel('Sample Index')
        plt.ylabel('Value')
        plt.legend()

    plt.tight_layout()
    plt.show()

# Plot the comparisons using the provided data
plot_comparisons(all_predictions_model1, all_predictions_model2, all_targets)

# %%
import matplotlib.pyplot as plt

# Plotting function
def plot_comparisons_compact(all_predictions_model1, all_predictions_model2, all_targets):
    titles = ["Mg Based Alloys", "Fe-Ni Based Alloys", "Al Based Alloys"]
    materials = len(all_predictions_model1)
    plt.figure(figsize=(8, 3 * materials))  # More compact figure size

    for i in range(materials):
        plt.subplot(materials, 1, i + 1)
        plt.plot(all_targets[i], 'o-', label='Ground Truth', markersize=4, alpha=0.8)  # Smaller markers
        plt.plot(all_predictions_model1[i], 'x-', label='Physics Constrained NN', markersize=4, alpha=0.7)
        plt.plot(all_predictions_model2[i], 's-', label='Traditional NN', markersize=4, alpha=0.6)
        plt.xlabel('Sample Index', fontsize=10)
        plt.ylabel('1/Rp', fontsize=10)
        plt.grid(False)  # No gridlines
        if i == 0:
            plt.legend(loc='upper left', fontsize=9)  # Legend in the upper left corner

    plt.tight_layout(pad=1.0)  # Tighter layout with minimal padding
    plt.show()

# Plot the comparisons using the provided data
plot_comparisons_compact(all_predictions_model1, all_predictions_model2, all_targets)

# %%
import matplotlib.pyplot as plt

# Plotting function
def plot_comparisons_compact(all_predictions_model1, all_predictions_model2, all_targets):
    titles = ["Mg Based Alloys", "Fe-Ni Based Alloys", "Al Based Alloys"]
    materials = len(all_predictions_model1)
    plt.figure(figsize=(8, 3 * materials))  # More compact figure size

    for i in range(materials):
        plt.subplot(materials, 1, i + 1)
        plt.plot(all_targets[i], 'o-', color='blue', label='Ground Truth', markersize=5, alpha=0.8)  # Consistent and distinct colors
        plt.plot(all_predictions_model1[i], 'x-', color='red', label='Physics Constrained NN', markersize=5, alpha=0.7)
        plt.plot(all_predictions_model2[i], 's-', color='green', label='Traditional NN', markersize=5, alpha=0.6)
        plt.xlabel('Sample Index', fontsize=12)
        plt.ylabel('1/Rp', fontsize=12)
        plt.title(titles[i], fontsize=14)
        plt.grid(False)  # No gridlines

        if i == 0:  # Display the legend only for the first subplot
            plt.legend(loc='upper left', fontsize=10)  # Legend inside the plot, top left

    plt.tight_layout(pad=1.0, h_pad=2.0)  # Tighter layout with minimal padding
    plt.show()

# Plot the comparisons using the provided data
plot_comparisons_compact(all_predictions_model1, all_predictions_model2, all_targets)
